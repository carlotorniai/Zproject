# %% [markdown]
# I have the stats on my words, educaiton and so on.
# I also have the values of skills in my dataframe.
#
# Let's try to figure out some hierarchical clustering.

# %% [markdown]
# I have saved a pandas dataframe i a pickle file generated with the build_skills_ds.py

# %%
import pymongo
import stats_fromdb as stats
import utils
import pandas as pd
import numpy as np
from collections import Counter
import operator
from scipy.spatial.distance import pdist, squareform
db, collection = utils.initializeDb("zproject", "ext_profiles_processed")
# Out:
# /Users/carlotorniai/anaconda/lib/python2.7/site-packages/pytz/__init__.py:35: UserWarning: Module argparse was already imported from /Users/carlotorniai/anaconda/lib/python2.7/argparse.pyc, but /Users/carlotorniai/anaconda/lib/python2.7/site-packages is being added to sys.path
#   from pkg_resources import resource_stream

# %%
df_skills, skill_list = stats.build_skills_ds(db, collection)
# Out:
# Building skills Df
# 1653

# %% [markdown]
# Now I want to do some hierarchical clustering with a subset of features.
# Using all th 1653 is really noisy.

# %% [markdown]
# Inspecting the list of the most common Skills we can see that it becomes really noisy ( general / too granular) after Hive (see below)

# %%
skills = Counter(skill_list)

# %%
skills
# Out:
# Counter({u'Machine Learning': 204, u'Data Mining': 183, u'R': 175, u'Python': 168, u'Data Analysis': 161, u'Statistics': 147, u'Big Data': 119, u'Hadoop': 115, u'Algorithms': 110, u'SQL': 107, u'Java': 103, u'Analytics': 95, u'Statistical Modeling': 93, u'Data Science': 86, u'Matlab': 85, u'Predictive Analytics': 77, u'Data Visualization': 70, u'Predictive Modeling': 69, u'Distributed Systems': 64, u'C++': 64, u'MySQL': 62, u'Mathematical Modeling': 62, u'MapReduce': 62, u'Artificial Intelligence': 57, u'Business Intelligence': 53, u'Databases': 52, u'LaTeX': 52, u'Natural Language Processing': 51, u'Analysis': 50, u'Information Retrieval': 49, u'Computer Science': 48, u'Programming': 48, u'SAS': 44, u'Text Mining': 42, u'Research': 42, u'Hive': 42, u'C': 40, u'Pattern Recognition': 40, u'Linux': 40, u'Software Development': 39, u'Software Engineering': 39, u'Perl': 38, u'Start-ups': 37, u'Optimization': 36, u'Scalability': 35, u'JavaScript': 34, u'Apache Pig': 33, u'Cloud Computing': 32, u'Time Series Analysis': 31, u'Physics': 30, u'Ruby': 30, u'Recommender Systems': 30, u'Strategy': 29, u'Entrepreneurship': 27, u'Product Management': 26, u'Data Modeling': 25, u'High Performance Computing': 25, u'Agile Methodologies': 25, u'Mathematica': 25, u'Monte Carlo Simulation': 23, u'Mathematics': 22, u'Project Management': 22, u'Applied Mathematics': 22, u'Scientific Computing': 21, u'Data Warehousing': 21, u'Git': 21, u'SPSS': 21, u'Quantitative Analytics': 20, u'